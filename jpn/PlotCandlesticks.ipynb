# %%
import plotly.graph_objects as go
import pandas as pd
from datetime import datetime, timedelta, date
import time

# %%
import os
from binance.client import Client
import pandas as pd
import datetime, time

# %%
for i in range(100):
    df = get_historical_data(2)
    fig = go.Figure(data=[go.Candlestick(x=df['dateTime'],
                    open=df['open'],
                    high=df['high'],
                    low=df['low'],
                    close=df['close'])])
    fig.show()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_860229/2219960168.py in <module>
#       2 for i in range(100):
#       3     df = get_historical_data(2)
# ----> 4     fig.add_trace([go.Candlestick(x=df['dateTime'],
#       5                     open=df['open'],
#       6                     high=df['high'],
#
# /mnt/BigSlowBoi/DOCUMENTS/Python/venv/binance_trading/lib/python3.8/site-packages/plotly/basedatatypes.py in add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#    2097             return self
#    2098
# -> 2099         return self.add_traces(
#    2100             data=[trace],
#    2101             rows=[row] if row is not None else None,
#
# /mnt/BigSlowBoi/DOCUMENTS/Python/venv/binance_trading/lib/python3.8/site-packages/plotly/basedatatypes.py in add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#    2181
#    2182         # Validate traces
# -> 2183         data = self._data_validator.validate_coerce(data)
#    2184
#    2185         # Set trace indexes
#
# /mnt/BigSlowBoi/DOCUMENTS/Python/venv/binance_trading/lib/python3.8/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2692
#    2693             if invalid_els:
# -> 2694                 self.raise_invalid_elements(invalid_els)
#    2695
#    2696             v = to_scalar_or_list(res)
#
# /mnt/BigSlowBoi/DOCUMENTS/Python/venv/binance_trading/lib/python3.8/site-packages/_plotly_utils/basevalidators.py in raise_invalid_elements(self, invalid_els)
#     303     def raise_invalid_elements(self, invalid_els):
#     304         if invalid_els:
# --> 305             raise ValueError(
#     306                 """
#     307     Invalid element(s) received for the '{name}' property of {pname}
#
# ValueError:
#     Invalid element(s) received for the 'data' property of
#         Invalid elements include: [[Candlestick({
#     'close': array(['0.00895600', '0.00895500', '0.00895400', '0.00895400', '0.00894800',
#                     '0.00894400', '0.00895300', '0.00894900', '0.00895500', '0.00895500',
#                     '0.00895700', '0.00894700', '0.00894600', '0.00895100', '0.00894800',
#                     '0.00894900', '0.00895100', '0.00895300', '0.00895000', '0.00895400',
#                     '0.00894300', '0.00894300', '0.00894200', '0.00891700', '0.00893500',
#                     '0.00893400', '0.00892800', '0.00892900', '0.00891600', '0.00892500',
#                     '0.00891300', '0.00891400', '0.00892400', '0.00892500', '0.00892500',
#                     '0.00892200', '0.00893000', '0.00892900', '0.00893800', '0.00893000',
#                     '0.00892800', '0.00892900', '0.00894200', '0.00893100', '0.00894300',
#                     '0.00894800', '0.00894800', '0.00895200', '0.00894700', '0.00894500',
#                     '0.00895300', '0.00895800', '0.00896300', '0.00896100', '0.00896600',
#                     '0.00896400', '0.00896500', '0.00895900', '0.00896200', '0.00896300',
#                     '0.00896400', '0.00895800', '0.00895000', '0.00894800', '0.00895400',
#                    '0.00897800', '0.00897600', '0.00897600', '0.00897700', '0.00897100',
#                    '0.00897500', '0.00897100', '0.00897800', '0.00898500', '0.00899400',
#                    '0.00898600', '0.00898300', '0.00898500', '0.00898800', '0.00898900',
#                    '0.00898600', '0.00899200', '0.00899500', '0.00899600', '0.00899500',
#                    '0.00899300', '0.00899200', '0.00898900', '0.00899400', '0.00899300',
#                    '0.00899000', '0.00898900', '0.00899200', '0.00899400', '0.00898500',
#                    '0.00898300', '0.00898300', '0.00898200', '0.00898300', '0.00898600'],
#                   dtype=object),
#     'x': array([datetime.datetime(2021, 11, 4, 7, 37),
#                 datetime.datetime(2021, 11, 4, 7, 38),
#                 datetime.datetime(2021, 11, 4, 7, 39),
#                 datetime.datetime(2021, 11, 4, 7, 40),
#                 datetime.datetime(2021, 11, 4, 7, 41),
#                 datetime.datetime(2021, 11, 4, 7, 42),
#                 datetime.datetime(2021, 11, 4, 7, 43),
#                 datetime.datetime(2021, 11, 4, 7, 44),
#                 datetime.datetime(2021, 11, 4, 7, 45),
#                 datetime.datetime(2021, 11, 4, 7, 46),
#                 datetime.datetime(2021, 11, 4, 7, 47),
#                 datetime.datetime(2021, 11, 4, 7, 48),
#                 datetime.datetime(2021, 11, 4, 7, 49),
#                 datetime.datetime(2021, 11, 4, 7, 50),
#                 datetime.datetime(2021, 11, 4, 7, 51),
#                 datetime.datetime(2021, 11, 4, 7, 52),
#                 datetime.datetime(2021, 11, 4, 7, 53),
#                 datetime.datetime(2021, 11, 4, 7, 54),
#                 datetime.datetime(2021, 11, 4, 7, 55),
#                 datetime.datetime(2021, 11, 4, 7, 56),
#                 datetime.datetime(2021, 11, 4, 7, 57),
#                 datetime.datetime(2021, 11, 4, 7, 58),
#                 datetime.datetime(2021, 11, 4, 7, 59),
#                 datetime.datetime(2021, 11, 4, 8, 0),
#                 datetime.datetime(2021, 11, 4, 8, 1),
#                 datetime.datetime(2021, 11, 4, 8, 2),
#                 datetime.datetime(2021, 11, 4, 8, 3),
#                 datetime.datetime(2021, 11, 4, 8, 4),
#                 datetime.datetime(2021, 11, 4, 8, 5),
#                 datetime.datetime(2021, 11, 4, 8, 6),
#                 datetime.datetime(2021, 11, 4, 8, 7),
#                 datetime.datetime(2021, 11, 4, 8, 8),
#                 datetime.datetime(2021, 11, 4, 8, 9),
#                 datetime.datetime(2021, 11, 4, 8, 10),
#                 datetime.datetime(2021, 11, 4, 8, 11),
#                 datetime.datetime(2021, 11, 4, 8, 12),
#                 datetime.datetime(2021, 11, 4, 8, 13),
#                 datetime.datetime(2021, 11, 4, 8, 14),
#                 datetime.datetime(2021, 11, 4, 8, 15),
#                 datetime.datetime(2021, 11, 4, 8, 16),
#                 datetime.datetime(2021, 11, 4, 8, 17),
#                 datetime.datetime(2021, 11, 4, 8, 18),
#                 datetime.datetime(2021, 11, 4, 8, 19),
#                 datetime.datetime(2021, 11, 4, 8, 20),
#                 datetime.datetime(2021, 11, 4, 8, 21),
#                 datetime.datetime(2021, 11, 4, 8, 22),
#                 datetime.datetime(2021, 11, 4, 8, 23),
#                 datetime.datetime(2021, 11, 4, 8, 24),
#                 datetime.datetime(2021, 11, 4, 8, 25),
#                 datetime.datetime(2021, 11, 4, 8, 26),
#                 datetime.datetime(2021, 11, 4, 8, 27),
#                 datetime.datetime(2021, 11, 4, 8, 28),
#                 datetime.datetime(2021, 11, 4, 8, 29),
#                 datetime.datetime(2021, 11, 4, 8, 30),
#                 datetime.datetime(2021, 11, 4, 8, 31),
#                 datetime.datetime(2021, 11, 4, 8, 32),
#                 datetime.datetime(2021, 11, 4, 8, 33),
#                 datetime.datetime(2021, 11, 4, 8, 34),
#                 datetime.datetime(2021, 11, 4, 8, 35),
#                 datetime.datetime(2021, 11, 4, 8, 36),
#                 datetime.datetime(2021, 11, 4, 8, 37),
#                 datetime.datetime(2021, 11, 4, 8, 38),
#                 datetime.datetime(2021, 11, 4, 8, 39),
#                 datetime.datetime(2021, 11, 4, 8, 40),
#                 datetime.datetime(2021, 11, 4, 8, 41),
#                 datetime.datetime(2021, 11, 4, 8, 42),
#                 datetime.datetime(2021, 11, 4, 8, 43),
#                 datetime.datetime(2021, 11, 4, 8, 44),
#                 datetime.datetime(2021, 11, 4, 8, 45),
#                 datetime.datetime(2021, 11, 4, 8, 46),
#                 datetime.datetime(2021, 11, 4, 8, 47),
#                 datetime.datetime(2021, 11, 4, 8, 48),
#                 datetime.datetime(2021, 11, 4, 8, 49),
#                 datetime.datetime(2021, 11, 4, 8, 50),
#                 datetime.datetime(2021, 11, 4, 8, 51),
#                 datetime.datetime(2021, 11, 4, 8, 52),
#                 datetime.datetime(2021, 11, 4, 8, 53),
#                 datetime.datetime(2021, 11, 4, 8, 54),
#                 datetime.datetime(2021, 11, 4, 8, 55),
#                 datetime.datetime(2021, 11, 4, 8, 56),
#                 datetime.datetime(2021, 11, 4, 8, 57),
#                 datetime.datetime(2021, 11, 4, 8, 58),
#                 datetime.datetime(2021, 11, 4, 8, 59),
#                 datetime.datetime(2021, 11, 4, 9, 0),
#                 datetime.datetime(2021, 11, 4, 9, 1),
#                 datetime.datetime(2021, 11, 4, 9, 2),
#                 datetime.datetime(2021, 11, 4, 9, 3),
#                 datetime.datetime(2021, 11, 4, 9, 4),
#                 datetime.datetime(2021, 11, 4, 9, 5),
#                 datetime.datetime(2021, 11, 4, 9, 6),
#                 datetime.datetime(2021, 11, 4, 9, 7),
#                 datetime.datetime(2021, 11, 4, 9, 8),
#                 datetime.datetime(2021, 11, 4, 9, 9),
#                 datetime.datetime(2021, 11, 4, 9, 10),
#                 datetime.datetime(2021, 11, 4, 9, 11),
#                 datetime.datetime(2021, 11, 4, 9, 12),
#                 datetime.datetime(2021, 11, 4, 9, 13),
#                 datetime.datetime(2021, 11, 4, 9, 14),
#                 datetime.datetime(2021, 11, 4, 9, 15),
#                 datetime.datetime(2021, 11, 4, 9, 16),
#                 datetime.datetime(2021, 11, 4, 9, 17),
#                 datetime.datetime(2021, 11, 4, 9, 18),
#                 datetime.datetime(2021, 11, 4, 9, 19),
#                 datetime.datetime(2021, 11, 4, 9, 20),
#                 datetime.datetime(2021, 11, 4, 9, 21),
#                 datetime.datetime(2021, 11, 4, 9, 22),
#                 datetime.datetime(2021, 11, 4, 9, 23),
#                 datetime.datetime(2021, 11, 4, 9, 24),
#                 datetime.datetime(2021, 11, 4, 9, 25),
#                 datetime.datetime(2021, 11, 4, 9, 26),
#                 datetime.datetime(2021, 11, 4, 9, 27),
#                 datetime.datetime(2021, 11, 4, 9, 28),
#                 datetime.datetime(2021, 11, 4, 9, 29),
#                 datetime.datetime(2021, 11, 4, 9, 30),
#                 datetime.datetime(2021, 11, 4, 9, 31),
#                 datetime.datetime(2021, 11, 4, 9, 32),
#                 datetime.datetime(2021, 11, 4, 9, 33),
#                 datetime.datetime(2021, 11, 4, 9, 34),
#                 datetime.datetime(2021, 11, 4, 9, 35),
#                 datetime.datetime(2021, 11, 4, 9, 36)], dtype=object)
# })]]
#
#     The 'data' property is a tuple of trace instances
#     that may be specified as:
#       - A list or tuple of trace instances
#         (e.g. [Scatter(...), Bar(...)])
#       - A single trace instance
#         (e.g. Scatter(...), Bar(...), etc.)
#       - A list or tuple of dicts of string/value properties where:
#         - The 'type' property specifies the trace type
#             One of: ['bar', 'barpolar', 'box', 'candlestick',
#                      'carpet', 'choropleth', 'choroplethmapbox',
#                      'cone', 'contour', 'contourcarpet',
#                      'densitymapbox', 'funnel', 'funnelarea',
#                      'heatmap', 'heatmapgl', 'histogram',
#                      'histogram2d', 'histogram2dcontour', 'icicle',
#                      'image', 'indicator', 'isosurface', 'mesh3d',
#                      'ohlc', 'parcats', 'parcoords', 'pie',
#                      'pointcloud', 'sankey', 'scatter',
#                      'scatter3d', 'scattercarpet', 'scattergeo',
#                      'scattergl', 'scattermapbox', 'scatterpolar',
#                      'scatterpolargl', 'scatterternary', 'splom',
#                      'streamtube', 'sunburst', 'surface', 'table',
#                      'treemap', 'violin', 'volume', 'waterfall']
#
#         - All remaining properties are passed to the constructor of
#           the specified trace type
#
#         (e.g. [{'type': 'scatter', ...}, {'type': 'bar, ...}])

# %%
# Out:
# /mnt/BigSlowBoi/DOCUMENTS/Python/venv/binance_trading/lib/python3.8/site-packages/dateparser/date_parser.py:35: PytzUsageWarning:
#
# The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html

# %%
# Out:
# <div>                            <div id="0c75e8ea-a48f-4d15-baf7-7edb25e50694" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0